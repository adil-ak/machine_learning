# %% [markdown]
# <a href="https://colab.research.google.com/github/adil-ak/machine_learning/blob/main/18Dec_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('tennis.csv')
df
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
df.shape
# Out:
# (14, 5)

# %%
df.isnull().sum()
# Out:
# outlook     0
# temp        0
# humidity    0
# windy       0
# play        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   outlook   14 non-null     object
#  1   temp      14 non-null     object
#  2   humidity  14 non-null     object
#  3   windy     14 non-null     bool
#  4   play      14 non-null     object
# dtypes: bool(1), object(4)
# memory usage: 590.0+ bytes

# %%
# !pip install category_encoders

# %%
import category_encoders as ce
encoder=ce.OneHotEncoder(cols=['outlook','temp','humidity'])
df=encoder.fit_transform(df)
df
# Out:
#     outlook_1  outlook_2  outlook_3  temp_1  temp_2  temp_3  humidity_1  humidity_2  windy play
# 0           1          0          0       1       0       0           1           0  False   no
# 1           1          0          0       1       0       0           1           0   True   no
# 2           0          1          0       1       0       0           1           0  False  yes
# 3           0          0          1       0       1       0           1           0  False  yes
# 4           0          0          1       0       0       1           0           1  False  yes
# 5           0          0          1       0       0       1           0           1   True   no
# 6           0          1          0       0       0       1           0           1   True  yes
# 7           1          0          0       0       1       0           1           0  False   no
# 8           1          0          0       0       0       1           0           1  False  yes
# ...

# %%
y=df['play']
x=df.drop(['play'],axis=1)

# %%
y
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12    yes
# 13     no
# Name: play, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.34164079, -0.63245553, -0.74535599,  1.58113883, -0.8660254 ,
#         -0.63245553,  1.        , -1.        , -0.8660254 ],
#        [ 1.34164079, -0.63245553, -0.74535599,  1.58113883, -0.8660254 ,
#         -0.63245553,  1.        , -1.        ,  1.15470054],
#        [-0.74535599,  1.58113883, -0.74535599,  1.58113883, -0.8660254 ,
#         -0.63245553,  1.        , -1.        , -0.8660254 ],
#        [-0.74535599, -0.63245553,  1.34164079, -0.63245553,  1.15470054,
#         -0.63245553,  1.        , -1.        , -0.8660254 ],
#        [-0.74535599, -0.63245553,  1.34164079, -0.63245553, -0.8660254 ,
#          1.58113883, -1.        ,  1.        , -0.8660254 ],
#        [-0.74535599, -0.63245553,  1.34164079, -0.63245553, -0.8660254 ,
#          1.58113883, -1.        ,  1.        ,  1.15470054],
#        [-0.74535599,  1.58113883, -0.74535599, -0.63245553, -0.8660254 ,
#          1.58113883, -1.        ,  1.        ,  1.15470054],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['no', 'no', 'yes'], dtype='<U3')

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6666666666666666

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.50      1.00      0.67         1
#          yes       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3

# %%
model.predict([[1,0,0,1,0,0,1,0,True]])
# Out:
# array(['yes'], dtype='<U3')
