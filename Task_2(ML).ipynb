# %% [markdown]
# <a href="https://colab.research.google.com/github/adil-ak/machine_learning/blob/main/Task_2(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("automobile_data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.loc[df.index[-10:],['height','curb-weight','engine-type','num-of-cylinders']]
# Out:
#      height  curb-weight engine-type num-of-cylinders
# 195    57.5         3034         ohc             four
# 196    56.2         2935         ohc             four
# 197    57.5         3042         ohc             four
# 198    56.2         3045         ohc             four
# 199    57.5         3157         ohc             four
# 200    55.5         2952         ohc             four
# 201    55.5         3049         ohc             four
# 202    55.5         3012        ohcv              six
# 203    55.5         3217         ohc              six
# 204    55.5         3062         ohc             four

# %%
df.loc[:10,['drive-wheels','wheel-base','length','width']]
# Out:
#    drive-wheels  wheel-base  length  width
# 0           rwd        88.6   168.8   64.1
# 1           rwd        88.6   168.8   64.1
# 2           rwd        94.5   171.2   65.5
# 3           fwd        99.8   176.6   66.2
# 4           4wd        99.4   176.6   66.4
# 5           fwd        99.8   177.3   66.3
# 6           fwd       105.8   192.7   71.4
# 7           fwd       105.8   192.7   71.4
# 8           fwd       105.8   192.7   71.4
# 9           4wd        99.5   178.2   67.9
# 10          rwd       101.2   176.8   64.8

# %%
df.loc[:,['fuel-system','bore','compression-ratio','stroke']]
# Out:
#     fuel-system  bore  compression-ratio stroke
# 0          mpfi  3.47                9.0   2.68
# 1          mpfi  3.47                9.0   2.68
# 2          mpfi  2.68                9.0   3.47
# 3          mpfi  3.19               10.0    3.4
# 4          mpfi  3.19                8.0    3.4
# ..          ...   ...                ...    ...
# 200        mpfi  3.78                9.5   3.15
# 201        mpfi  3.78                8.7   3.15
# 202        mpfi  3.58                8.8   2.87
# 203         idi  3.01               23.0    3.4
# 204        mpfi  3.78                9.5   3.15
#
# [205 rows x 4 columns]

# %%
df[50:71]
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 50          1               104          mazda       gas        std
# 51          1               104          mazda       gas        std
# 52          1               104          mazda       gas        std
# 53          1               113          mazda       gas        std
# 54          1               113          mazda       gas        std
# 55          3               150          mazda       gas        std
# 56          3               150          mazda       gas        std
# 57          3               150          mazda       gas        std
# 58          3               150          mazda       gas        std
# 59          1               129          mazda       gas        std
# 60          0               115          mazda       gas        std
# 61          1               129          mazda       gas        std
# 62          0               115          mazda       gas        std
# ...

# %%
df[['bore','stroke','compression-ratio','horsepower']]
# Out:
#      bore stroke  compression-ratio horsepower
# 0    3.47   2.68                9.0        111
# 1    3.47   2.68                9.0        111
# 2    2.68   3.47                9.0        154
# 3    3.19    3.4               10.0        102
# 4    3.19    3.4                8.0        115
# ..    ...    ...                ...        ...
# 200  3.78   3.15                9.5        114
# 201  3.78   3.15                8.7        160
# 202  3.58   2.87                8.8        134
# 203  3.01    3.4               23.0        106
# 204  3.78   3.15                9.5        114
#
# [205 rows x 4 columns]

# %%
df.iloc[150:171,-5:-2]
# Out:
#     horsepower peak-rpm  city-mpg
# 150         62     4800        35
# 151         62     4800        31
# 152         62     4800        31
# 153         62     4800        31
# 154         62     4800        27
# 155         62     4800        27
# 156         70     4800        30
# 157         70     4800        30
# 158         56     4500        34
# 159         56     4500        38
# 160         70     4800        38
# 161         70     4800        28
# 162         70     4800        28
# 163         70     4800        29
# 164         70     4800        29
# 165        112     6600        26
# 166        112     6600        26
# 167        116     4800        24
# 168        116     4800        24
# 169        116     4800        24
# 170        116     4800        24

# %%
df.iloc[-5:,:10]
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base
# 200      sedan          rwd           front       109.1
# 201      sedan          rwd           front       109.1
# 202      sedan          rwd           front       109.1
# 203      sedan          rwd           front       109.1
# 204      sedan          rwd           front       109.1

# %%
df.iloc[-10:-1,-5:]
# Out:
#     horsepower peak-rpm  city-mpg  highway-mpg  price
# 195        114     5400        23           28  13415
# 196        114     5400        24           28  15985
# 197        114     5400        24           28  16515
# 198        162     5100        17           22  18420
# 199        162     5100        17           22  18950
# 200        114     5400        23           28  16845
# 201        160     5300        19           25  19045
# 202        134     5500        18           23  21485
# 203        106     4800        26           27  22470

# %%
df.iloc[195:-5,:]
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 195         -1                74  volvo       gas        std         four
# 196         -2               103  volvo       gas        std         four
# 197         -1                74  volvo       gas        std         four
# 198         -2               103  volvo       gas      turbo         four
# 199         -1                74  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 195      wagon          rwd           front       104.3  ...          141
# 196      sedan          rwd           front       104.3  ...          141
# 197      wagon          rwd           front       104.3  ...          141
# 198      sedan          rwd           front       104.3  ...          130
# 199      wagon          rwd           front       104.3  ...          130
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df.iloc[:151,7:]
# Out:
#     drive-wheels engine-location  wheel-base  length  width  height  \
# 0            rwd           front        88.6   168.8   64.1    48.8
# 1            rwd           front        88.6   168.8   64.1    48.8
# 2            rwd           front        94.5   171.2   65.5    52.4
# 3            fwd           front        99.8   176.6   66.2    54.3
# 4            4wd           front        99.4   176.6   66.4    54.3
# ..           ...             ...         ...     ...    ...     ...
# 146          fwd           front        97.0   173.5   65.4    53.0
# 147          fwd           front        97.0   173.5   65.4    53.0
# 148          4wd           front        96.9   173.6   65.4    54.9
# 149          4wd           front        96.9   173.6   65.4    54.9
# 150          fwd           front        95.7   158.7   63.6    54.5
#
#      curb-weight engine-type num-of-cylinders  engine-size fuel-system  bore  \
# ...
